# %% [markdown]
# #### Зайцев Артем (стажер)

# %% [markdown]
# ## Задание №1

# %% [raw]
# У нас есть импортированный модуль foo, как узнать физический путь файла, откуда он импортирован?

# %% [raw]
# Путь к модулю хранится в аттрибуте __file__ импортированного модуля

# %% [markdown]
# ## Задание № 2

# %% [raw]
# Из модуля foo вы импортируете модуль feedparser. Версия X feedparser'а есть в общесистемном каталоге site-packages, версия Y — рядом с модулем foo. Определена переменная окружения PYTHONPATH, и там тоже есть feedparser, версии Z. Какая версия будет использоваться?

# %% [raw]
# Так как при импортировании модуля интерпретатор сначала ищет его в текущем каталоге (а затем уже в каталогах, указанных в переменной окружения PYTHONPATH и каталогах, указанных по умолчанию при установке), то использоваться будет версия Y модуля feedparser.

# %% [markdown]
# ## Задание №3

# %% [raw]
# Как посмотреть список каталогов, в которых Python ищет модули?

# %% [raw]
# Переменная sys.path представляет из себя список строк, определяющий путь поиска модулей интерпретатора. Она инициализируется значением пути по умолчанию, взятым из переменной окружения PYTHONPATH, или встроенным значением по умолчанию, если PYTHONPATH не установлен.

# %% [markdown]
# ## Задание №4

# %% [raw]
# У вас есть модуль foo, внутри него импортируется модуль bar. Рядом с модулем foo есть файлы bar.py и bar/__init__.py Какой модуль будет использоваться.

# %% [raw]
# Касательно использования выражения "from пакет import элемент" (в котором элементом может быть как подмодуль (или подпакет) пакета, так или любое другое имя) я прочёл следующее: оператор import сначала проверяет, определён ли элемент в пакете, если нет — он трактует его как модуль и пытается загрузить. Таким образом, я думаю, что конструкция import считает приоритетным элемент, то есть в нашем случае bar.py

# %% [markdown]
# ## Задание №5

# %% [raw]
# Что означает и для чего используется конструкция __name__ == '__main__'

# %% [raw]
# Переменная __name__ будет равна "__main__" в том случае, если модуль запущен как самостоятельная программа. В случае же если он импортирован, __name__ будет равна имени модуля.
